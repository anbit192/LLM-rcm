# %%
import pandas as pd
from datetime import datetime

# %%
df = pd.read_csv("../data/movie_infos_2.csv")
df.set_index("movieId", inplace=True)

# %%
dict_ = {1: 1, 2: 2, 3: 3}
list(dict_.keys())
# Out:
# [1, 2, 3]

# %%
datetime.now().strftime("%Y-%m-%d %H:%M:%S")
# Out:
# '2025-03-12 13:19:33'

# %%
idx = [1, 2, 3]

df.loc[idx]
# Out:
#          vectorID                    title  \
# movieId
# 1               0         Toy Story (1995)
# 2               1           Jumanji (1995)
# 3               2  Grumpier Old Men (1995)
#
#                                               genres  \
# movieId
# 1        Adventure,Animation,Children,Comedy,Fantasy
# 2                         Adventure,Children,Fantasy
# 3                                     Comedy,Romance
#
#                                                       tags  weight_rating  \
# movieId
# 1        adventure,animated,animation,cartoon,cgi,child...       3.904516
# 2        adventure,animals,big budget,childhood,childre...       3.214918
# 3               comedy,good sequel,original,sequel,sequels       3.161619
#
#             imdbId                                       page_content
# movieId
# 1        tt0114709  Movie's title: Toy Story (1995)\ngenres: Adven...
# 2        tt0113497  Movie's title: Jumanji (1995)\ngenres: Adventu...
# ...
